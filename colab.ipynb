# %%
# !git clone https://github.com/iioSnail/csc_tools.git
# %cd csc_tools
# !pip install -r requirements.txt
# Out:
# Cloning into 'csc_tools'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 41 (delta 12), reused 37 (delta 11), pack-reused 0
# Receiving objects: 100% (41/41), 198.20 KiB | 8.26 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# /content/csc_tools
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 25.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 42.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 22.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 63.4 MB/s eta 0:00:00
# ...

# %%
# 在运行之后，点击"your url is"后面的链接。弹出的页面需要填写密码，密码就是"External URL"的IP（注意：只有IP）。之后你就可以看到页面了
# After running this code, please click the link behind "your url is". The page needs you to input a password that is the IP of "External URL". Note, only IP. And then, you can access the page.
# !streamlit run streamlit_demo.py & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 35.197.0.103
# [..................] \ fetchMetadata: sill resolveWithNewModule yargs@17.1.1 ch
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.197.0.103:8501
#
# npx: installed 22 in 2.585s
# your url is: https://tricky-dogs-drop.loca.lt
# model_name: macbert4csc
# device: cpu
# self.device: cpu
# model_name: ChineseBertForCSC(SCOPE)
# device: cpu
# vocab.txt: 100% 118k/118k [00:00<00:00, 929kB/s]
# tokenizer.json: 100% 481k/481k [00:00<00:00, 2.44MB/s]
# special_tokens_map.json: 100% 125/125 [00:00<00:00, 385kB/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'http_user_agent' (from 'huggingface_hub.file_download') is deprecated and will be removed from version '0.22.0'. Use `huggingface_hub.utils.build_hf_headers` instead.
#   warnings.warn(warning_message, FutureWarning)
# config/pinyin_map.json: 100% 466/466 [00:00<00:00, 1.37MB/s]
# ...
